# %% [markdown]
# # 1. Recommender system
# När du tittar på Youtube, beställer mat online, köper böcker online, lyssnar på Spotify, använder LinkedIn så
# får du ständigt rekommendationer för nya videoklipp, maträtter mm. Det som ligger bakom dessa är en typ
# av recommender system.

# %% [markdown]
# # 1.0 - Uppvärmning
# Börja med att kolla på denna youtube-video och följ efter i kod för att skapa ett enkelt recommender system
# för filmer med hjälp av KNN. Datasetet som används i videon är från movielens small som består av 100,000
# ratings på 9000 filmer och 600 användare.
# Lämna inte in denna delen, utan gör den för egen skull.

# %%
import pandas as pd 
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import process

# %%
movies =  '../data/ml-latest-small/movies.csv'
ratings = '../data/ml-latest-small/ratings.csv'

df_movies = pd.read_csv(movies, usecols= ['movieId', 'title'], dtype={'movieId': 'int32', 'title': 'str'})
df_ratings = pd.read_csv(ratings, usecols=["userId", "movieId", "rating"], dtype={"userId": "int32", "movieId": "int32", "rating": "float32"})

# %%
df_movies.head()
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %% [markdown]
# # Spares Matrix

# %%
# spare matrix 
#         [4,4,5]
#Movies    [3,3,4]
#       [3,2,1]

movies_users = df_ratings.pivot(index="movieId", columns="userId", values="rating").fillna(0)
mat_movies_users = csr_matrix(movies_users.values)

# %%
#Eclidean distance
#Manhattan distance 
#Minkowski distance
#cosine similarity 
model_knn = NearestNeighbors(metric="cosine", algorithm="brute", n_neighbors=20)

# %%
model_knn.fit(mat_movies_users)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=20)

# %% [markdown]
# # recommender function

# %%
# recommender function (movie_name) = >List of movies recommended

def recommender (movie_name, data, model, n_recommendations  ):
    model.fit(data)
    idx = process.extractOne("movie_name", df_movies["title"])[2]
    print('Movie Selected:', df_movies['title'][idx], 'Index: ', idx)
    print('Searching for recommendations......')
    distances, indices = model.kneighbors(data[idx], n_neighbors = n_recommendations)
    for i in indices:
        print(df_movies['title'][i].where(i!=idx))

recommender('Iron man', mat_movies_users, model_knn, 20)
# Out:
# Movie Selected: Man with the Movie Camera, The (Chelovek s kino-apparatom) (1929) Index:  4386
# Searching for recommendations......
# 4207                               Kiss Me Goodbye (1982)
# 5044                        I Walked with a Zombie (1943)
# 5579    Visions of Light: The Art of Cinematography (1...
# 5565                      Mannequin 2: On the Move (1991)
# 5875    Before the Fall (NaPolA - Elite für den Führer...
# 6286                               Wicker Man, The (2006)
# 5507                            Love at First Bite (1979)
# 6279                                    Invincible (2006)
# 4660                                  OT: Our Town (2002)
# 847               Single Girl, A (Fille seule, La) (1995)
# 4651                                  Missing, The (2003)
# 5522                           Death of a Salesman (1985)
# 3436                         War of the Roses, The (1989)
# 3423                                   Sea of Love (1989)
# 6267                                     Mind Game (2004)
# 3414                            Planet of the Apes (2001)
# 870                                   Lesson Faust (1994)
# 4198                                  Recruit, The (2003)
# 5873                        Amityville Horror, The (2005)
# 6257                                    Miami Vice (2006)
# Name: title, dtype: object
